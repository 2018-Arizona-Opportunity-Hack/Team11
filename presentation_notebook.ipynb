# %%
from questionaire_reader import QuestionnaireReader

# %%
q_reader = QuestionnaireReader('https://alfarains.com/hackathon/pl/upload/files/Scanned_Surveys.pdf')

# %%
q_reader.compare_images(116, 112, q_reader.page_1_questions['question_2']['b'])

# %%
q_reader.translate_pages()
